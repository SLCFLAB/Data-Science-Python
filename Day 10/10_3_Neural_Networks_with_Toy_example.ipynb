# %% [markdown]
# <a href="https://colab.research.google.com/github/SLCFLAB/Data-Science-Python/blob/main/Day%2010/10_3_Neural_Networks_with_Toy_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Networks with Toy example

# %% [markdown]
# 출처: https://github.com/Harry24k/Pytorch-Basic

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Generate Data

# %%
x = torch.linspace(-1, 1, 500)
y = x.pow(3) + 0.2*torch.rand(x.size())

plt.scatter(x.data.numpy(), y.data.numpy())
plt.show()

# %%
x.shape, y.shape
# Out:
# (torch.Size([500]), torch.Size([500]))

# %%
x = torch.unsqueeze(x, dim=1)
y = torch.unsqueeze(y, dim=1)

# %% [markdown]
# ## 2. Define Model

# %%
hidden1 = nn.Linear(1, 10, bias=True)
# activation1 = nn.ReLU()

hidden2 = nn.Linear(10, 20, bias=True)
# activation2 = nn.ReLU()

hidden3 = nn.Linear(20, 10, bias=True)
# activation3 = nn.ReLU()

output = nn.Linear(10, 1, bias=True)

# %%
model = nn.Sequential(
    hidden1, 
    # activation1,
    hidden2, 
    # activation2,
    hidden3, 
    # activation3,
    output
)

# %%
loss = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# ## 3. Train Model

# %%
for step in range(2000):
    pre = model(x) ## hidden에 activation 있을때와 없을 때
    cost = loss(pre, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if step % 400  == 0:
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), pre.data.numpy(), 'r--', lw=4)
        plt.text(0.5, 0, 'Loss=%.4f' % cost.item(), fontdict={'size':10, 'color':'red'})
        plt.show()
