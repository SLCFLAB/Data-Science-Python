# %% [markdown]
# <a href="https://colab.research.google.com/github/SLCFLAB/Data-Science-Python/blob/main/Day%2011/11_1_CNN_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Construct a CNN Model

# %% [markdown]
# 출처: https://github.com/Harry24k/Pytorch-Basic

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# CNN은 convolution layer를 사용해 filter 연산을 함.
# ![ICLH_Diagram_Batch_02_17A-ConvolutionalNeuralNetworks-WHITEBG[1].png](data:image/png;base64,...)
#
# 출처: https://www.ibm.com/cloud/learn/convolutional-neural-networks

# %% [markdown]
# - CNN 모델은 일반적으로 covolution과 pooling layer로 구성되어 있음(보통 그 사이에 ReLU layer을 넣지만, 최근 연구결과 순서를 바꿔도 됨이 밝혀짐)
# - filter을 이용해 연산을 하면 크기가 줄어듦, padding을 통해 이를 해결할 수 있음.
# - pooling을 통해 중요한 정보만 남게 할 수 있음. 보통 max pooling을 사용하며, 예를들어 2*2 max pooling을 하면 크기는 반으로 줄어듦.
# - stride를 통해 건너뛰면서 연산을 할 수도 있음.

# %% [markdown]
# - input : N * N
# - padding : P
# - stride : S
# - Filter : F * F
#
# 라고 할 때,

# %% [markdown]
# ### output = {[(N+2P-F)/S] + 1} * {[(N+2P-F)/S] + 1}
# 여기서 []는 가우스기호

# %% [markdown]
# 직접 계산을 해 봅시다!

# %% [markdown]
# 빈칸을 모두 채워서 실행 결과가 True가 나오는 파일 제출하기

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 1, 24, 24)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 1, ?)
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-4-68258fb5ff61>", line 2
#     nn.Conv2d(1, 1, ?)
#                     ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 3, 28, 28)

# %%
model = nn.Sequential(
    nn.Conv2d(1, ?, 1),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-6-c1cde848a89e>", line 2
#     nn.Conv2d(1, ?, 1),
#                  ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 1, 30, 30)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 1, 1, padding=?),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-8-4736fbb924bf>", line 2
#     nn.Conv2d(1, 1, 1, padding=?),
#                                ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 1, 20, 20)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 1, 5),
    nn.ReLU(),
    nn.Conv2d(1, 1, ?),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-10-c71805c4667b>", line 4
#     nn.Conv2d(1, 1, ?),
#                     ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 10, 22, 22)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 3, 5),
    nn.ReLU(),
    nn.Conv2d(?, ?, 3),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-12-37a99df5eba6>", line 4
#     nn.Conv2d(?, ?, 3),
#               ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 32, 26, 26)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 4, 4, padding=2),
    nn.ReLU(),
    nn.Conv2d(4, 32, ?),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-14-51ad4d847464>", line 4
#     nn.Conv2d(4, 32, ?),
#                      ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 64, 19, 19)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 4, 4),
    nn.ReLU(),
    nn.Conv2d(4, 32, 4),
    nn.ReLU(),
    nn.Conv2d(32, ?, ?),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-16-d18b14ffda35>", line 6
#     nn.Conv2d(32, ?, ?),
#                   ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 64, 8, 8)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 4, 4),
    nn.ReLU(),
    nn.Conv2d(4, 32, 4, stride=?),
    nn.ReLU(),
    nn.Conv2d(32, 64, 4),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-18-866c8c7612d5>", line 4
#     nn.Conv2d(4, 32, 4, stride=?),
#                                ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 64, 8, 8)

# %%
model = nn.Sequential(
    nn.Conv2d(1, 4, 4),
    nn.ReLU(),
    nn.Conv2d(4, 32, 4),
    nn.ReLU(),
    nn.MaxPool2d(?, ?),
    nn.Conv2d(32, 64, 4),
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-20-6427087b2a22>", line 6
#     nn.MaxPool2d(?, ?),
#                  ^
# SyntaxError: invalid syntax

# %%
X = torch.rand(100, 1, 28, 28)
Y = torch.rand(100, 64, 3, 3)

# %%
model = nn.Sequential(
    nn.Conv2d(1, ?, 5),
    nn.ReLU(),
    nn.Conv2d(16, 32, 5),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),
    nn.Conv2d(?, 64, ?),
    nn.ReLU(),
    nn.MaxPool2d(2, 2)
)

model(X).shape == Y.shape
# Out:
#   File "<ipython-input-22-1b59518bb110>", line 2
#     nn.Conv2d(1, ?, 5),
#                  ^
# SyntaxError: invalid syntax
